# %% [markdown]
# <a href="https://colab.research.google.com/github/ctun3610-byte/MMDT_T-PY101_Batch03/blob/main/chan_min_tun_Ex04_Homework_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf
#
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print the characters of the string one-by-one on separate lines.

# %%
a_string = input("enter a string - ")
index = 0

while index < len(a_string):
  print(a_string[index])
  index = index+1
# Out:
# enter a string - chan min tun
# c
# h
# a
# n
#
# m
# i
# n
#
# t
# u
# n

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that asks the user for a weight and converts it from kilograms to pounds. Whenever the user enters a weight below 0, the program should tell them that their entry is invalid and then ask them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
weight_in_kg = float(input("Enter the weight in kilograms : "))

while weight_in_kg < 0:
  print("The entry is invalid, enter again!")
  weight_in_kg = float(input("Enter the weight in kilograms : "))

pounds = weight_in_kg * 2.2
print("{} kg is equal to {} pounds".format(weight_in_kg,pounds))
# Out:
# Enter the weight in kilograms : -1
# The entry is invalid, enter again!
# Enter the weight in kilograms : 1
# 1.0 kg is equal to 2.2 pounds

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates they are done by entering in a negative number. Print how many of the scores are A’s (90 or above). Also print out the average

# %%
total = 0
count = 0
a_score_count = 0

score = float(input("Enter a score: "))

while score >= 0:
    count += 1
    total += score
    if score >= 90:
        a_score_count += 1
    score = float(input("Enter a score: "))

if count > 0:
    print("Number of A's scores:", a_score_count)
    print("Average scores:", total / count)
else:
    print("No scores entered.")
# Out:
# Enter a score: 10
# Enter a score: 50
# Enter a score: 90
# Enter a score: -1
# Number of A's scores: 1
# Average scores: 50.0

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the program should print the index of the first occurrence of that letter and a message if the string does not contain the letter.

# %%
text = input("Enter a string = ")
letter = input("Enter a letter to find = ")
index = 0

for index in range(len(text)):
    if text[index] == letter:
        print("First occurrence of '{}' is at index {}".format(letter,index))
        break
else:
    print("The letter '{}' was not found".format(letter))
# Out:
# Enter a string = chan min tun
# Enter a letter to find = m
# First occurrence of 'm' is at index 5

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
number_list = [1, 0, 1, 0, 1, 0, 1]

for i in range(len(number_list)):
    if number_list[i] == 0:
       number_list[i] = 1
       print("new list:", number_list)
       break
else:
    print("There are no zero entries in the list.")
# Out:
# new list: [1, 1, 1, 0, 1, 0, 1]
