# %% [markdown]
# <a href="https://colab.research.google.com/github/ctun3610-byte/MMDT_T-PY101_Batch03/blob/main/chan_min_tun_Ex01_Homework_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ex 1 : Check Version
# Using the below cell, Import the required library and check the version of the python in your environment.

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# Ex2 : Convert Currency.
# Write a program that asks the user for the amount in usd and converts it to British pounds. The exchange rate is from usd to BP is given as 0.82

# %%
usd = input("number of usd =")
british_pounds = int(usd) * 0.82

print("{} USD is equal to {} British pounds.".format(usd, british_pounds))
# Out:
# number of usd =100
# 100 USD is equal to 82.0 British pounds.

# %% [markdown]
# Ex 3: Temperature Converter
# Write a program that convert temperature in Feranhite to celsius.

# %%
degree_feranhite = input("Temperature in Feranhite = ")
degree_celsius =  (int(degree_feranhite)-32) * 5/9

print("{} degree Feranhite is equal to {} degree Celsius".format(degree_feranhite, degree_celsius))
# Out:
# Temperature in Feranhite = 32
# 32 degree Feranhite is equal to 0.0 degree Celsius

# %% [markdown]
# Ex 4: Daily Maths
# You are working in a retail shop. Write a program that computes the total cost for a customer that bought 3 differnt types of fruits : apple, orange, mango. Ask the user to enter the quantity and price for each type.

# %%
apple_quantity = input('number of apple -')
apple_price = input ( 'price of apple -')

orange_quantity = input ('number of orange -')
orange_price = input ( 'price of orange -')

mango_quantity = input ('number of mango -')
mango_price = input ( 'price of mango -')

total_cost = int(apple_quantity) * int(apple_price) + int(orange_quantity) * int(orange_price) + int(mango_quantity) * int(mango_price)

print("Total Cost - {} USD".format(total_cost))
# Out:
# number of apple -3
# price of apple -1
# number of orange -2
# price of orange -1
# number of mango -4
# price of mango -1
# Total Cost - 9 USD

# %% [markdown]
# Ex 5 : Greeting
# Write a program to greet the customer who provides the user name. Your program should ask the name of the customer and print "Hello + customer name"

# %%
customer_name = input("Enter your name please - ")
print("Hello " + customer_name)
# Out:
# Enter your name please - Chan
# Hello Chan

# %% [markdown]
# Ex 6: Random Number
# Write a program that generates a random number, x, between 1 and 50, a random number y between 2 and 5, and computes x^y.

# %%
from random import randint
x = randint(1,50)
y = randint(2,5)
computes = x**y

print('Random number of x =',x)
print('Random number of y =',y)
print("The result of x^y  =",computes)
# Out:
# Random number of x = 8
# Random number of y = 2
# The result of x^y  = 64

# %% [markdown]
# Ex 7: Greet many times.
# Write a program that generates a random number between 1 and 10 and prints your name that many times.

# %%
from random import randint
x = randint(1,10)
user_name = input('Tell me your name - ')

print("Your name will be written {} times".format(x))
print(user_name * x)
# Out:
# Tell me your name - Chan
# Your name will be written 7 times
# ChanChanChanChanChanChanChan

# %% [markdown]
# Ex 8: Computing.
# Write a program that asks the user to enter two numbers, x and y, and computes |x-y|/(x+y).

# %%
x = input("Please Type First Number = ")
y = input("Please Type Second Number = ")

computes = (int(x)-int(y))/(int(x)+int(y))

print("Result of |x-y|/(x+y) = ",computes)
# Out:
# Please Type First Number = 3
# Please Type Second Number = 1
# Result of |x-y|/(x+y) =  0.5

# %% [markdown]
# Ex 9: Computing
# Write a program that asks the user for a number of seconds and prints out how many minutes and seconds that is. For instance, 200 seconds is 3 minutes and 20 seconds.

# %%
x = input("Enter a number of seconds = ")
minutes = int(x)//60
seconds = int(x) % 60
print("That is {} minutes and {} seconds. ".format (minutes,seconds))
# Out:
# Enter a number of seconds = 310
# That is 5 minutes and 10 seconds.

# %% [markdown]
# Ex 10: Using Math Module
# Write a program that asks the user for a number and then prints out the sine, cosine, and tangent of that number.

# %%
import math
x = float(input("Please enter a number = "))
radians = math.radians(x)

sin = math.sin(radians)
cos = math.cos (radians)
tan = math.tan (radians)

print("sine = ",sin)
print("cosine = ",cos)
print("tangent = ",tan)
# Out:
# Please enter a number = 30
# sine =  0.49999999999999994
# cosine =  0.8660254037844387
# tangent =  0.5773502691896257
